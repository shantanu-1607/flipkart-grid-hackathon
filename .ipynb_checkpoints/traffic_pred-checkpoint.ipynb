# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# %%
train=pd.read_csv('dataset/train.csv')
test=pd.read_csv('dataset/test.csv')

# %%
train.sample(5)
# Out:
#        Index geohash  day timestamp    demand     RoadType  NumberofLanes  \
# 30306  30306  qp09g9   48      8:30  0.000746  Residential              2
# 72805  72805  qp0djd   49      0:45  0.007800  Residential              3
# 39472  39472  qp06pm   48      11:0  0.005459  Residential              1
# 25544  25544  qp03rg   48      7:15  0.084261  Residential              3
# 59684  59684  qp03rz   48      19:0  0.013344  Residential              1
#
#       LargeVehicles Landmarks  Temperature Weather
# 30306   Not Allowed       Yes     9.605062   Rainy
# 72805       Allowed       Yes    25.217511   Sunny
# 39472   Not Allowed        No    10.005066   Rainy
# 25544       Allowed       Yes          NaN   Sunny
# 59684   Not Allowed        No    25.537454   Sunny

# %%
test.sample(5)
# Out:
#        Index geohash  day timestamp     RoadType  NumberofLanes LargeVehicles  \
# 1336    1336  qp09sc   49      2:30  Residential              3       Allowed
# 41255  41255  qp096k   49     13:45  Residential              2   Not Allowed
# 9572    9572  qp03wf   49      4:45      Highway              5       Allowed
# 31265  31265  qp0987   49     10:45      Highway              5       Allowed
# 22840  22840  qp03px   49      8:30  Residential              3       Allowed
#
#       Landmarks  Temperature Weather
# 1336        Yes    21.042171   Sunny
# 41255       Yes     9.631483   Rainy
# 9572         No    10.977914   Rainy
# 31265        No     2.025721   Snowy
# 22840       Yes    17.178153   Foggy

# %%
train.dtypes
# Out:
# Index              int64
# geohash           object
# day                int64
# timestamp         object
# demand           float64
# RoadType          object
# NumberofLanes      int64
# LargeVehicles     object
# Landmarks         object
# Temperature      float64
# Weather           object
# dtype: object

# %%
test.dtypes
# Out:
# Index              int64
# geohash           object
# day                int64
# timestamp         object
# RoadType          object
# NumberofLanes      int64
# LargeVehicles     object
# Landmarks         object
# Temperature      float64
# Weather           object
# dtype: object

# %%
train.isnull().sum()
test.isnull().sum() ## hence some null values
# Out:
# Index               0
# geohash             0
# day                 0
# timestamp           0
# RoadType          324
# NumberofLanes       0
# LargeVehicles       0
# Landmarks           0
# Temperature      1349
# Weather           431
# dtype: int64

# %%
train.shape
# Out:
# (77299, 11)

# %%
test.shape
# Out:
# (41778, 10)

# %%
train.describe()
# Out:
#               Index           day        demand  NumberofLanes   Temperature
# count  77299.000000  77299.000000  7.729900e+04   77299.000000  74804.000000
# mean   38649.000000     48.101838  9.394238e-02       2.014334     16.405354
# std    22314.443566      0.302438  1.421905e-01       0.904665      7.359835
# min        0.000000     48.000000  6.245650e-07       1.000000    -14.935097
# 25%    19324.500000     48.000000  1.822723e-02       1.000000     11.430473
# 50%    38649.000000     48.000000  4.775994e-02       2.000000     16.382587
# 75%    57973.500000     48.000000  1.085951e-01       3.000000     21.298833
# max    77298.000000     49.000000  1.000000e+00       5.000000     48.251433

# %%
test.describe()
# Out:
#              Index      day  NumberofLanes   Temperature
# count  41778.00000  41778.0   41778.000000  40429.000000
# mean   20888.50000     49.0       2.068984     16.457339
# std    12060.41411      0.0       0.988519      7.351067
# min        0.00000     49.0       1.000000    -21.314645
# 25%    10444.25000     49.0       1.000000     11.527029
# 50%    20888.50000     49.0       2.000000     16.471232
# 75%    31332.75000     49.0       3.000000     21.365883
# max    41777.00000     49.0       5.000000     45.230408

# %%
## decoding geohash into readble number

# %%
base32 = '0123456789bcdefghjkmnpqrstuvwxyz'

# %%
all_geohashes = list(set(list(train['geohash']) + list(test['geohash'])))
all_geohashes
# Out:
# ['qp03xz',
#  'qp03r1',
#  'qp08bk',
#  'qp03py',
#  'qp06ps',
#  'qp09ds',
#  'qp09gk',
#  'qp09uj',
#  'qp03y0',
#  'qp0d50',
#  'qp0d0t',
#  'qp095u',
#  'qp09eq',
#  'qp0d4c',
#  'qp08fv',
#  'qp090x',
#  'qp09gv',
#  'qp03xk',
#  'qp02zd',
#  'qp0dhd',
#  'qp0d07',
#  'qp0953',
#  'qp03pm',
#  'qp03jx',
#  'qp03x8',
#  'qp03td',
#  'qp0dj7',
#  'qp08fp',
#  'qp0956',
#  'qp09u0',
#  'qp0dh6',
#  'qp03pz',
#  'qp03r2',
#  'qp0dhg',
#  'qp09gj',
#  'qp09uw',
#  'qp09hq',
#  'qp0988',
#  'qp03px',
#  'qp03t8',
#  'qp09gg',
#  'qp095j',
#  'qp09jq',
#  'qp096t',
#  'qp06pv',
#  'qp09he',
#  'qp09b6',
#  'qp09fm',
#  'qp03q0',
#  'qp08gw',
#  'qp0djc',
#  'qp03z9',
#  'qp09uy',
#  'qp09kx',
#  'qp098j',
#  'qp0d00',
#  'qp091z',
#  'qp03zy',
#  'qp03z7',
#  'qp099c',
#  'qp0djf',
#  'qp03y9',
#  'qp06p6',
#  'qp03mr',
#  'qp03xf',
#  'qp0d5j',
#  'qp03zf',
#  'qp09bm',
#  'qp09kr',
#  'qp09ch',
#  'qp09db',
#  'qp03r0',
#  'qp09c7',
#  'qp09ce',
#  'qp03qn',
#  'qp09t8',
#  'qp08cv',
#  'qp09u3',
#  'qp09ur',
#  'qp099h',
#  'qp09h0',
#  'qp03y4',
#  'qp09bv',
#  'qp08g7',
#  'qp090h',
#  'qp09mq',
#  'qp08bt',
#  'qp097m',
#  'qp03tq',
#  'qp03yx',
#  'qp09t9',
#  'qp03rx',
#  'qp03m2',
#  'qp090p',
#  'qp03zh',
#  'qp097c',
#  'qp0d5e',
#  'qp09vq',
#  'qp09u6',
#  'qp09sn',
#  'qp0984',
#  'qp03r6',
#  'qp099n',
#  'qp09me',
#  'qp03y1',
#  'qp09ck',
#  'qp09sj',
#  'qp08gx',
#  'qp093v',
#  'qp08fn',
#  'qp094n',
#  'qp06pm',
#  'qp08fw',
#  'qp09fu',
#  'qp0983',
#  'qp09cr',
#  'qp03r8',
#  'qp0d4q',
#  'qp096w',
#  'qp03xp',
#  'qp0960',
#  'qp0d53',
#  'qp0d1w',
#  'qp09mw',
#  'qp08bw',
#  'qp09bd',
#  'qp095r',
#  'qp03m8',
#  'qp09vs',
#  'qp03rc',
#  'qp08cj',
#  'qp03te',
#  'qp03z4',
#  'qp0dhu',
#  'qp09kb',
#  'qp0987',
#  'qp09m8',
#  'qp09dr',
#  'qp09uk',
#  'qp098k',
#  'qp03qp',
#  'qp094z',
#  'qp02zh',
#  'qp0948',
#  'qp099p',
#  'qp03r5',
#  'qp02z4',
#  'qp09jp',
#  'qp03zv',
#  'qp09fx',
#  'qp06ph',
#  'qp02z7',
#  'qp06pu',
#  'qp09s8',
#  'qp099f',
#  'qp0971',
#  'qp03yt',
#  'qp03qj',
#  'qp09b7',
#  'qp09g8',
#  'qp09fj',
#  'qp09fy',
#  'qp03q2',
#  'qp0djg',
#  'qp09b3',
#  'qp03pn',
#  'qp0d1j',
#  'qp09h6',
#  'qp08bz',
#  'qp02zr',
#  'qp03mb',
#  'qp03wb',
#  'qp09dw',
#  'qp0d17',
#  'qp09ek',
#  'qp09fb',
#  'qp03nb',
#  'qp03xd',
#  'qp095t',
#  'qp0d1k',
#  'qp0994',
#  'qp03yr',
#  'qp090s',
#  'qp0945',
#  'qp03mf',
#  'qp03jw',
#  'qp08cn',
#  'qp09u4',
#  'qp0d4u',
#  'qp06p0',
#  'qp0dj2',
#  'qp093t',
#  'qp03wg',
#  'qp090d',
#  'qp03p1',
#  'qp09dt',
#  'qp06pf',
#  'qp03q1',
#  'qp09c8',
#  'qp09ec',
#  'qp09ew',
#  'qp0d4v',
#  'qp09h7',
#  'qp0943',
#  'qp03x2',
#  'qp09e1',
#  'qp03pr',
#  'qp03x7',
#  'qp097p',
#  'qp03wt',
#  'qp03w6',
#  'qp03nz',
#  'qp09ju',
#  'qp09gf',
#  'qp03zc',
#  'qp09ss',
#  'qp09v0',
#  'qp099u',
#  'qp03rr',
#  'qp09jk',
#  'qp09hw',
#  'qp03wz',
#  'qp098v',
#  'qp03mt',
#  'qp03jq',
#  'qp09jv',
#  'qp0d1h',
#  'qp08bq',
#  'qp0djm',
#  'qp09g0',
#  'qp03q8',
#  'qp097b',
#  'qp09k4',
#  'qp09dj',
#  'qp03qt',
#  'qp09f7',
#  'qp09cd',
#  'qp0968',
#  'qp090w',
#  'qp0d5b',
#  'qp09mn',
#  'qp097k',
#  'qp0dj6',
#  'qp0djb',
#  'qp09ep',
#  'qp09ff',
#  'qp03yc',
#  'qp03qc',
#  'qp03yy',
#  'qp0921',
#  'qp03zr',
#  'qp096q',
#  'qp0946',
#  'qp0d0u',
#  'qp09eu',
#  'qp03xn',
#  'qp03w0',
#  'qp0d5m',
#  'qp0d0f',
#  'qp0dhh',
#  'qp06p2',
#  'qp0985',
#  'qp09kz',
#  'qp094p',
#  'qp09yp',
#  'qp09c2',
#  'qp096h',
#  'qp090b',
#  'qp099z',
#  'qp09h5',
#  'qp02yc',
#  'qp03zk',
#  'qp03nq',
#  'qp08bv',
#  'qp09c9',
#  'qp0dn4',
#  'qp0dnj',
#  'qp09s1',
#  'qp0d4h',
#  'qp03jz',
#  'qp0d02',
#  'qp06pj',
#  'qp03rp',
#  'qp09s6',
#  'qp06p1',
#  'qp0980',
#  'qp0d15',
#  'qp09kc',
#  'qp09c6',
#  'qp09jc',
#  'qp0d5g',
#  'qp094w',
#  'qp03q9',
#  'qp03zb',
#  'qp093c',
#  'qp09m9',
#  'qp09hy',
#  'qp0995',
#  'qp090k',
#  'qp09b1',
#  'qp0d4b',
#  'qp03vc',
#  'qp09dd',
#  'qp09n4',
#  'qp0961',
#  'qp09bj',
#  'qp0d58',
#  'qp096b',
#  'qp090e',
#  'qp0dj9',
#  'qp09mc',
#  'qp03rj',
#  'qp03zd',
#  'qp097r',
#  'qp02zm',
#  'qp03qy',
#  'qp095x',
#  'qp09tm',
#  'qp09vn',
#  'qp09e6',
#  'qp0999',
#  'qp09t5',
#  'qp03z6',
#  'qp03wq',
#  'qp0d0y',
#  'qp098q',
#  'qp09s3',
#  'qp0d1y',
#  'qp02zs',
#  'qp0954',
#  'qp096j',
#  'qp0d1g',
#  'qp02zy',
#  'qp09ev',
#  'qp098b',
#  'qp03pp',
#  'qp09kn',
#  'qp08fy',
#  'qp098p',
#  'qp095c',
#  'qp08g6',
#  'qp03qw',
#  'qp03pt',
#  'qp03x9',
#  'qp0979',
#  'qp09cw',
#  'qp09vk',
#  'qp02zu',
#  'qp09hr',
#  'qp094q',
#  'qp03t9',
#  'qp091t',
#  'qp09st',
#  'qp03qd',
#  'qp0dj5',
#  'qp092e',
#  'qp03tm',
#  'qp08gj',
#  'qp08gu',
#  'qp08fq',
#  'qp09ke',
#  'qp096u',
#  'qp08bm',
#  'qp09sk',
#  'qp09up',
#  'qp03qx',
#  'qp09uu',
#  'qp09e4',
#  'qp0djy',
#  'qp0931',
#  'qp09sb',
#  'qp0d1b',
#  'qp097s',
#  'qp09gb',
#  'qp097v',
#  'qp03x4',
#  'qp09v4',
#  'qp06py',
#  'qp09gx',
#  'qp09bz',
#  'qp091w',
#  'qp08b1',
#  'qp09gh',
#  'qp0920',
#  'qp0dj4',
#  'qp09v8',
#  'qp03ze',
#  'qp0d04',
#  'qp09y1',
#  'qp09wp',
#  'qp09vj',
#  'qp03tv',
#  'qp093n',
#  'qp09hs',
#  'qp098g',
#  'qp0dh9',
#  'qp09q4',
#  'qp03yn',
#  'qp08c5',
#  'qp0906',
#  'qp03xj',
#  'qp0969',
#  'qp09js',
#  'qp0dhk',
#  'qp03qg',
#  'qp03pw',
#  'qp09d2',
#  'qp03pf',
#  'qp09b5',
#  'qp0djt',
#  'qp09cs',
#  'qp03rd',
#  'qp0d14',
#  'qp09fg',
#  'qp02yz',
#  'qp09fe',
#  'qp09er',
#  'qp08up',
#  'qp0d5d',
#  'qp0d06',
#  'qp0936',
#  'qp091s',
#  'qp0dn1',
#  'qp0927',
#  'qp09jt',
#  'qp09d5',
#  'qp08be',
#  'qp09g7',
#  'qp095q',
#  'qp03q7',
#  'qp08un',
#  'qp03q6',
#  'qp03rt',
#  'qp090c',
#  'qp0d12',
#  'qp02zp',
#  'qp094t',
#  'qp0970',
#  'qp03nn',
#  'qp092q',
#  'qp0djk',
#  'qp08bx',
#  'qp0958',
#  'qp03r7',
#  'qp09m3',
#  'qp097t',
#  'qp03zu',
#  'qp09mx',
#  'qp094u',
#  'qp08gt',
#  'qp09gm',
#  'qp09hv',
#  'qp09cb',
#  'qp095m',
#  'qp0937',
#  'qp09d6',
#  'qp06nc',
#  'qp09hz',
#  'qp09yj',
#  'qp03xt',
#  'qp090r',
#  'qp096p',
#  'qp09fr',
#  'qp03qz',
#  'qp0922',
#  'qp09qp',
#  'qp094c',
#  'qp09tt',
#  'qp03yq',
#  'qp097f',
#  'qp09b4',
#  'qp096v',
#  'qp09fz',
#  'qp09u2',
#  'qp03ys',
#  'qp09es',
#  'qp0djw',
#  'qp097n',
#  'qp03wp',
#  'qp092r',
#  'qp09jf',
#  'qp03ws',
#  'qp09tx',
#  'qp09km',
#  'qp03yd',
#  'qp0djj',
#  'qp09ve',
#  'qp06nd',
#  'qp096g',
#  'qp099e',
#  'qp08br',
#  'qp0903',
#  'qp03tr',
#  'qp03yk',
#  'qp03qh',
#  'qp0957',
#  'qp09v2',
#  'qp03xr',
#  'qp091u',
#  'qp0d16',
#  'qp06pk',
#  'qp03pk',
#  'qp090z',
#  'qp03ny',
#  'qp091q',
#  'qp03mv',
#  'qp0d0m',
#  'qp02z5',
#  'qp09ue',
#  'qp06ng',
#  'qp09jx',
#  'qp0dh0',
#  'qp09m1',
#  'qp0941',
#  'qp097j',
#  'qp0d1q',
#  'qp09mm',
#  'qp09tk',
#  'qp099m',
#  'qp09jj',
#  'qp093h',
#  'qp096m',
#  'qp09k8',
#  'qp0dnh',
#  'qp0dn0',
#  'qp09jb',
#  'qp03rn',
#  'qp0dhv',
#  'qp0d55',
#  'qp09h1',
#  'qp09t4',
#  'qp0dnn',
#  'qp094v',
#  'qp03r4',
#  'qp03p7',
#  'qp03tb',
#  'qp09e3',
#  'qp09eh',
#  'qp08fx',
#  'qp09g2',
#  'qp08bu',
#  'qp091e',
#  'qp06pc',
#  'qp098r',
#  'qp096y',
#  'qp0d48',
#  'qp03zg',
#  'qp09vg',
#  'qp03zp',
#  'qp0977',
#  'qp09u9',
#  'qp08fr',
#  'qp09ub',
#  'qp0d4t',
#  'qp094y',
#  'qp02z9',
#  'qp09b0',
#  'qp0d0w',
#  'qp09dq',
#  'qp0917',
#  'qp095s',
#  'qp09de',
#  'qp03we',
#  'qp03ty',
#  'qp097q',
#  'qp02z1',
#  'qp091r',
#  'qp09cu',
#  'qp03wu',
#  'qp0981',
#  'qp08gn',
#  'qp0932',
#  'qp09ej',
#  'qp095g',
#  'qp0dh8',
#  'qp06pw',
#  'qp03r9',
#  'qp03x0',
#  'qp09d7',
#  'qp095h',
#  'qp0905',
#  'qp03zq',
#  'qp09k7',
#  'qp094s',
#  'qp03p0',
#  'qp09mj',
#  'qp09ee',
#  'qp092x',
#  'qp093b',
#  'qp097h',
#  'qp096k',
#  'qp09em',
#  'qp08gv',
#  'qp03wf',
#  'qp0d5q',
#  'qp08gz',
#  'qp098n',
#  'qp093z',
#  'qp08gh',
#  'qp06pq',
#  'qp03nr',
#  'qp09hp',
#  'qp09e7',
#  'qp09e9',
#  'qp094h',
#  'qp03yw',
#  'qp0944',
#  'qp09dg',
#  'qp09gq',
#  'qp092s',
#  'qp09sm',
#  'qp0d0n',
#  'qp09s7',
#  'qp03z8',
#  'qp093x',
#  'qp097g',
#  'qp08cy',
#  'qp0d0s',
#  'qp03r3',
#  'qp0978',
#  'qp0963',
#  'qp096r',
#  'qp03v9',
#  'qp03tf',
#  'qp03x3',
#  'qp0965',
#  'qp03zj',
#  'qp09s2',
#  'qp03mm',
#  'qp09f0',
#  'qp09mr',
#  'qp096c',
#  'qp03mx',
#  'qp03rg',
#  'qp08gm',
#  'qp03q4',
#  'qp09cf',
#  'qp093q',
#  'qp03qs',
#  'qp08cm',
#  'qp093g',
#  'qp0dh5',
#  'qp03rb',
#  'qp09cq',
#  'qp03p6',
#  'qp0d52',
#  'qp03xb',
#  'qp09dp',
#  'qp09ft',
#  'qp03ru',
#  'qp09ks',
#  'qp03w2',
#  'qp09f4',
#  'qp09s9',
#  'qp09uq',
#  'qp09m0',
#  'qp09bn',
#  'qp02yf',
#  'qp09ms',
#  'qp09g6',
#  'qp0d0k',
#  'qp091y',
#  'qp09tn',
#  'qp08bj',
#  'qp09su',
#  'qp03p8',
#  'qp09f3',
#  'qp03qb',
#  'qp03p9',
#  'qp0993',
#  'qp092n',
#  'qp098m',
#  'qp094g',
#  'qp098d',
#  'qp09dc',
#  'qp09um',
#  'qp0djs',
#  'qp03qu',
#  'qp06p4',
#  'qp09sr',
#  'qp03wh',
#  'qp0dju',
#  'qp09je',
#  'qp03x5',
#  'qp03q3',
#  'qp097e',
#  'qp09cz',
#  'qp0d4s',
#  'qp03rz',
#  'qp03pd',
#  'qp09us',
#  'qp09vt',
#  'qp093u',
#  'qp09yh',
#  'qp093f',
#  'qp094j',
#  'qp094m',
#  'qp03wm',
#  'qp03yg',
#  'qp08g4',
#  'qp02zq',
#  'qp06ne',
#  'qp03mk',
#  'qp08ck',
#  'qp09kw',
#  'qp094r',
#  'qp091v',
#  'qp09gc',
#  'qp03rq',
#  'qp03y6',
#  'qp09u8',
#  'qp09y0',
#  'qp08bg',
#  'qp099w',
#  'qp03q5',
#  'qp02zv',
#  'qp09u7',
#  'qp03tu',
#  'qp09np',
#  'qp0949',
#  'qp02zx',
#  'qp08gr',
#  'qp092w',
#  'qp03wr',
#  'qp0d03',
#  'qp03nx',
#  'qp02z3',
#  'qp09s4',
#  'qp0dh3',
#  'qp03m6',
#  'qp03p5',
#  'qp06pg',
#  'qp0dh1',
#  'qp09fd',
#  'qp0dhw',
#  'qp09sg',
#  'qp09vr',
#  'qp095z',
#  'qp0dhf',
#  'qp0938',
#  'qp09sp',
#  'qp09cg',
#  'qp097x',
#  'qp09sq',
#  'qp02zc',
#  'qp03wc',
#  'qp0908',
#  'qp095y',
#  'qp09u1',
#  'qp09h4',
#  'qp09bk',
#  'qp09v1',
#  'qp03wk',
#  'qp09fs',
#  'qp06pe',
#  'qp09bt',
#  'qp0djq',
#  'qp0dh7',
#  'qp0dj1',
#  'qp03t6',
#  'qp0d59',
#  'qp09f9',
#  'qp02ze',
#  'qp08by',
#  'qp0952',
#  'qp0975',
#  'qp03xe',
#  'qp094k',
#  'qp09jn',
#  'qp03tz',
#  'qp09gy',
#  'qp091n',
#  'qp090n',
#  'qp09d8',
#  'qp0923',
#  'qp09sc',
#  'qp09hj',
#  'qp09ug',
#  'qp0dhy',
#  'qp0dhm',
#  'qp03zt',
#  'qp09ux',
#  'qp093k',
#  'qp03xs',
#  'qp099r',
#  'qp0d01',
#  'qp08b6',
#  'qp090q',
#  'qp09yn',
#  'qp09ef',
#  'qp08uj',
#  'qp09fh',
#  'qp096s',
#  'qp09k5',
#  'qp0d49',
#  'qp03rv',
#  'qp09w0',
#  'qp0dhq',
#  'qp0d4y',
#  'qp09jr',
#  'qp03tt',
#  'qp03jr',
#  'qp0976',
#  'qp09sz',
#  'qp08gp',
#  'qp094e',
#  'qp09cy',
#  'qp03rs',
#  'qp0d4e',
#  'qp09vv',
#  'qp090m',
#  'qp09du',
#  'qp09tp',
#  'qp0d1f',
#  'qp09g4',
#  'qp02zz',
#  'qp02zj',
#  'qp09fq',
#  'qp09uv',
#  'qp09hk',
#  'qp093p',
#  'qp09fc',
#  'qp095v',
#  'qp0d0h',
#  'qp095k',
#  'qp03mg',
#  'qp0d5c',
#  'qp03zs',
#  'qp02yy',
#  'qp0djn',
#  'qp09ky',
#  'qp0d0q',
#  'qp09ge',
#  'qp0d0b',
#  'qp03p4',
#  'qp03qr',
#  'qp09en',
#  'qp0924',
#  'qp099v',
#  'qp09be',
#  'qp09vp',
#  'qp03yv',
#  'qp06ns',
#  'qp0dhj',
#  'qp09k2',
#  'qp09uh',
#  'qp093y',
#  'qp09md',
#  'qp03pc',
#  'qp095b',
#  'qp096n',
#  'qp06pt',
#  'qp0902',
#  'qp09sd',
#  'qp03yu',
#  'qp09mb',
#  'qp03pv',
#  'qp09ct',
#  'qp09ht',
#  'qp095f',
#  'qp09jd',
#  'qp096x',
#  'qp03yz',
#  'qp03qf',
#  'qp0d1v',
#  'qp0d5h',
#  'qp09q1',
#  'qp03qm',
#  'qp06nb',
#  'qp0d1m',
#  'qp0d05',
#  'qp09mt',
#  'qp09kv',
#  'qp03wv',
#  'qp03y7',
#  'qp09ut',
#  'qp09fv',
#  'qp094x',
#  'qp098h',
#  'qp09bq',
#  'qp02zn',
#  'qp09bh',
#  'qp03t2',
#  'qp0dj8',
#  'qp03md',
#  'qp03z0',
#  'qp09dv',
#  'qp06p9',
#  'qp03tw',
#  'qp09e8',
#  'qp09cm',
#  'qp09gt',
#  'qp092p',
#  'qp09se',
#  'qp0929',
#  'qp0dht',
#  'qp06nf',
#  'qp09tv',
#  'qp093m',
#  'qp092t',
#  'qp08bh',
#  'qp03qk',
#  'qp098e',
#  'qp0d1n',
#  'qp09w4',
#  'qp03np',
#  'qp0d0g',
#  'qp09d9',
#  'qp09ed',
#  'qp09v7',
#  'qp0d4g',
#  'qp096e',
#  'qp091d',
#  'qp091g',
#  'qp091m',
#  'qp03mq',
#  'qp0dje',
#  'qp09vu',
#  'qp03w5',
#  'qp09t2',
#  'qp09vc',
#  'qp03ye',
#  'qp0990',
#  'qp08fh',
#  'qp094b',
#  'qp08fz',
#  'qp0909',
#  'qp0d4n',
#  'qp09fk',
#  'qp09j7',
#  'qp03p3',
#  'qp0d5f',
#  'qp0951',
#  'qp09v3',
#  'qp092m',
#  'qp0d1t',
#  'qp03my',
#  'qp099d',
#  'qp03pb',
#  'qp06p5',
#  'qp0d0c',
#  'qp09tj',
#  'qp09sy',
#  'qp03pe',
#  'qp09gu',
#  'qp03w4',
#  'qp02zf',
#  'qp0996',
#  'qp0934',
#  'qp03qq',
#  'qp03pq',
#  'qp0d11',
#  'qp09e5',
#  'qp09vf',
#  'qp09vx',
#  'qp09bw',
#  'qp03tg',
#  'qp03me',
#  'qp03zz',
#  'qp092h',
#  'qp0d1c',
#  'qp091x',
#  'qp09m2',
#  'qp09k0',
#  'qp09gn',
#  'qp0925',
#  'qp095w',
#  'qp03t7',
#  'qp097w',
#  'qp09bx',
#  'qp0901',
#  'qp09ud',
#  'qp09gz',
#  'qp03m3',
#  'qp03qe',
#  'qp09f1',
#  'qp09mz',
#  'qp06n9',
#  'qp03xh',
#  'qp09sv',
#  'qp09cn',
#  'qp09t0',
#  'qp09v6',
#  'qp08gs',
#  'qp09gs',
#  'qp03zn',
#  'qp03z1',
#  'qp08fj',
#  'qp09dx',
#  'qp09jm',
#  'qp09k1',
#  'qp09cc',
#  'qp03w8',
#  'qp0d19',
#  'qp0d57',
#  'qp09th',
#  'qp03wn',
#  'qp09kf',
#  'qp0973',
#  'qp02zw',
#  ...]

# %%
gh_lat = {}
gh_lon = {}

# %%
for gh in all_geohashes:
    lat_lo, lat_hi = -90.0, 90.0
    lon_lo, lon_hi = -180.0, 180.0
    even = True
    for ch in gh:
        cd = base32.index(ch)
        for mask in [16, 8, 4, 2, 1]:
            if even:
                mid = (lon_lo + lon_hi) / 2
                if cd & mask:
                    lon_lo = mid
                else:
                    lon_hi = mid
            else:
                mid = (lat_lo + lat_hi) / 2
                if cd & mask:
                    lat_lo = mid
                else:
                    lat_hi = mid
            even = not even
    gh_lat[gh] = (lat_lo + lat_hi) / 2
    gh_lon[gh] = (lon_lo + lon_hi) / 2

# %%
len(gh_lat)
# Out:
# 1259

# %%
gh_lon
# Out:
# {'qp03xz': 90.6976318359375,
#  'qp03r1': 90.6646728515625,
#  'qp08bk': 90.7196044921875,
#  'qp03py': 90.6976318359375,
#  'qp06ps': 90.6866455078125,
#  'qp09ds': 90.8184814453125,
#  'qp09gk': 90.8514404296875,
#  'qp09uj': 90.8843994140625,
#  'qp03y0': 90.6207275390625,
#  'qp0d50': 90.8404541015625,
#  'qp0d0t': 90.7305908203125,
#  'qp09sv': 90.9173583984375,
#  'qp09cn': 90.7525634765625,
#  'qp09t0': 90.9283447265625,
#  'qp09v6': 90.9393310546875,
#  'qp08gs': 90.8624267578125,
#  'qp09gs': 90.8624267578125,
#  'qp03zn': 90.6646728515625,
#  'qp03z1': 90.6646728515625,
#  'qp08fj': 90.7965087890625,
#  'qp09dx': 90.8184814453125,
#  'qp09jm': 90.9393310546875,
#  'qp09k1': 90.8843994140625,
#  'qp09cc': 90.7855224609375,
#  'qp03w8': 90.6427001953125,
#  'qp0d19': 90.7745361328125,
#  'qp0d57': 90.8514404296875,
#  'qp09th': 90.9283447265625,
#  'qp03wn': 90.6207275390625,
#  'qp09kf': 90.9173583984375,
#  'qp0973': 90.8514404296875,
#  'qp02zw': 90.6866455078125,
#  ...}

# %%
for df in [train, test]:
    # timestamp like "2:15" -> minutes since midnight
    df['tmin'] = df['timestamp'].str.split(':').str[0].astype(int) * 60 \
               + df['timestamp'].str.split(':').str[1].astype(int)
    df['hour'] = df['tmin'] // 60
    df['tod_bucket'] = df['tmin'] // 30          # 30-minute slot of the day

    # cyclical time: tells the model that 23:45 and 00:00 are close together
    df['min_sin']  = np.sin(2 * np.pi * df['tmin'] / 1440)
    df['min_cos']  = np.cos(2 * np.pi * df['tmin'] / 1440)
    df['hour_sin'] = np.sin(2 * np.pi * df['hour'] / 24)
    df['hour_cos'] = np.cos(2 * np.pi * df['hour'] / 24)

    # location from the decoded geohash
    df['lat'] = df['geohash'].map(gh_lat)
    df['lon'] = df['geohash'].map(gh_lon)

    # coarser region codes + location-time combos
    df['gh_prefix5'] = df['geohash'].str[:5]
    df['gh_prefix4'] = df['geohash'].str[:4]
    df['gh_hour']    = df['geohash'] + '_' + df['hour'].astype(str)
    df['gh_bucket']  = df['geohash'] + '_' + df['tod_bucket'].astype(str)

# %%
train['temp_missing'] = train['Temperature'].isna().astype(int)
test['temp_missing']  = test['Temperature'].isna().astype(int) ## figuring out null values in temp in a column

# %%
train.sample(5)
# Out:
#        Index geohash  day timestamp    demand     RoadType  NumberofLanes  \
# 35024  35024  qp02zx   48      10:0  0.431004      Highway              2
# 29940  29940  qp0925   48      8:30  0.227186       Street              1
# 51535  51535  qp09ky   48     14:45  0.010008  Residential              3
# 33218  33218  qp02zw   48      9:30  0.745726      Highway              4
# 54255  54255  qp03t7   48     15:45  0.004112  Residential              2
#
#       LargeVehicles Landmarks  Temperature  ...   min_cos  hour_sin  hour_cos  \
# 35024       Allowed        No    17.686021  ... -0.866025  0.500000 -0.866025
# 29940   Not Allowed       Yes    15.191175  ... -0.608761  0.866025 -0.500000
# 51535       Allowed       Yes    19.684627  ... -0.751840 -0.500000 -0.866025
# 33218       Allowed       Yes     6.892753  ... -0.793353  0.707107 -0.707107
# 54255   Not Allowed       Yes    10.708605  ... -0.555570 -0.707107 -0.707107
#
#             lat        lon  gh_prefix5  gh_prefix4    gh_hour  gh_bucket  \
# 35024 -5.451965  90.686646       qp02z        qp02  qp02zx_10  qp02zx_20
# 29940 -5.386047  90.708618       qp092        qp09   qp0925_8  qp0925_17
# 51535 -5.369568  90.917358       qp09k        qp09  qp09ky_14  qp09ky_29
# 33218 -5.457458  90.686646       qp02z        qp02   qp02zw_9  qp02zw_19
# 54255 -5.342102  90.587769       qp03t        qp03  qp03t7_15  qp03t7_31
#
#        temp_missing
# 35024             0
# 29940             0
# 51535             0
# 33218             0
# 54255             0
#
# [5 rows x 25 columns]

# %%
temp_by_gh = train.groupby('geohash')['Temperature'].median()
glob_temp  = train['Temperature'].median()
train['Temperature'] = train['Temperature'].fillna(train['geohash'].map(temp_by_gh)).fillna(glob_temp)
test['Temperature']  = test['Temperature'].fillna(test['geohash'].map(temp_by_gh)).fillna(glob_temp) ## filling the missing temp values with median

# %%
train.sample(5)
# Out:
#        Index geohash  day timestamp    demand     RoadType  NumberofLanes  \
# 45114  45114  qp096s   48     12:45  0.014064  Residential              3
# 22744  22744  qp03rb   48      6:30  0.022175  Residential              3
# 55444  55444  qp03xm   48     16:15  0.454733      Highway              2
# 501      501  qp03yc   48       0:0  0.042732  Residential              1
# 11524  11524  qp0dhe   48      3:15  0.059775  Residential              2
#
#       LargeVehicles Landmarks  Temperature  ...   min_cos      hour_sin  \
# 45114       Allowed       Yes     7.897293  ... -0.980785  1.224647e-16
# 22744       Allowed       Yes     6.854368  ... -0.130526  1.000000e+00
# 55444       Allowed        No     6.618569  ... -0.442289 -8.660254e-01
# 501     Not Allowed        No    15.240663  ...  1.000000  0.000000e+00
# 11524   Not Allowed       Yes    31.006925  ...  0.659346  7.071068e-01
#
#            hour_cos       lat        lon  gh_prefix5  gh_prefix4    gh_hour  \
# 45114 -1.000000e+00 -5.380554  90.818481       qp096        qp09  qp096s_12
# 22744  6.123234e-17 -5.402527  90.697632       qp03r        qp03   qp03rb_6
# 55444 -5.000000e-01 -5.331116  90.675659       qp03x        qp03  qp03xm_16
# 501    1.000000e+00 -5.309143  90.653687       qp03y        qp03   qp03yc_0
# 11524  7.071068e-01 -5.254211  90.906372       qp0dh        qp0d   qp0dhe_3
#
#        gh_bucket  temp_missing
# 45114  qp096s_25             0
# 22744  qp03rb_13             0
# 55444  qp03xm_32             0
# 501     qp03yc_0             0
# 11524   qp0dhe_6             0
#
# [5 rows x 25 columns]

# %%
for df in [train, test]:
    df['LargeVehicles_e'] = (df['LargeVehicles'] == 'Allowed').astype(int)
    df['Landmarks_e']     = (df['Landmarks'] == 'Yes').astype(int)

road_dummies = pd.get_dummies(pd.concat([train['RoadType'], test['RoadType']]), prefix='road', dummy_na=True)
train_road = road_dummies.iloc[:len(train)].reset_index(drop=True)
test_road  = road_dummies.iloc[len(train):].reset_index(drop=True)
for c in train_road.columns:
    train[c] = train_road[c].astype(int)
    test[c]  = test_road[c].astype(int)

weather_dummies = pd.get_dummies(pd.concat([train['Weather'], test['Weather']]), prefix='weather', dummy_na=True)
train_weather = weather_dummies.iloc[:len(train)].reset_index(drop=True)
test_weather  = weather_dummies.iloc[len(train):].reset_index(drop=True)
for c in train_weather.columns:
    train[c] = train_weather[c].astype(int)
    test[c]  = test_weather[c].astype(int)

road_cols = [c for c in train.columns if c.startswith('road_')]
weather_cols = [c for c in train.columns if c.startswith('weather_')]

# %%
for df in [train, test]:
    df['temp_x_hour']    = df['Temperature'] * df['hour']
    df['lanes_x_road']   = df['NumberofLanes'] * df['LargeVehicles_e']
    df['lanes_x_hour']   = df['NumberofLanes'] * df['hour']
    df['lat_x_lon']      = df['lat'] * df['lon']
    df['temp_x_lanes']   = df['Temperature'] * df['NumberofLanes']

# %%
train.sample(5)
# Out:
#        Index geohash  day timestamp    demand     RoadType  NumberofLanes  \
# 41223  41223  qp06p5   48     11:30  0.183051  Residential              1
# 40554  40554  qp03nx   48     11:30  0.052617  Residential              1
# 51201  51201  qp06pc   48     14:30  0.010517  Residential              1
# 49877  49877  qp094x   48     14:15  0.093400  Residential              3
# 52775  52775  qp094r   48     15:15  0.277845       Street              1
#
#       LargeVehicles Landmarks  Temperature  ... weather_Foggy  weather_Rainy  \
# 41223   Not Allowed        No    25.858567  ...             0              0
# 40554   Not Allowed        No    13.618576  ...             0              1
# 51201   Not Allowed        No    11.318643  ...             0              1
# 49877       Allowed       Yes    15.978656  ...             1              0
# 52775   Not Allowed       Yes    15.655103  ...             1              0
#
#        weather_Snowy  weather_Sunny  weather_nan  temp_x_hour  lanes_x_road  \
# 41223              0              1            0   284.444235             0
# 40554              0              0            0   149.804331             0
# 51201              0              0            0   158.461006             0
# 49877              0              0            0   223.701184             3
# 52775              0              0            0   234.826550             0
#
#        lanes_x_hour   lat_x_lon  temp_x_lanes
# 41223            11 -476.371360     25.858567
# 40554            11 -490.197537     13.618576
# 51201            14 -477.540967     11.318643
# 49877            42 -491.148166     47.935968
# 52775            15 -491.088752     15.655103
#
# [5 rows x 41 columns]

# %%
# !pip install lightgbm catboost
# Out:
# Requirement already satisfied: lightgbm in /opt/anaconda3/lib/python3.13/site-packages (4.6.0)
# Requirement already satisfied: catboost in /opt/anaconda3/lib/python3.13/site-packages (1.2.10)
# Requirement already satisfied: numpy>=1.17.0 in /opt/anaconda3/lib/python3.13/site-packages (from lightgbm) (2.3.5)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.13/site-packages (from lightgbm) (1.16.3)
# Requirement already satisfied: graphviz in /opt/anaconda3/lib/python3.13/site-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.13/site-packages (from catboost) (3.10.6)
# Requirement already satisfied: pandas<4.0,>=0.24 in /opt/anaconda3/lib/python3.13/site-packages (from catboost) (2.3.3)
# Requirement already satisfied: plotly in /opt/anaconda3/lib/python3.13/site-packages (from catboost) (6.3.0)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.13/site-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.13/site-packages (from pandas<4.0,>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas<4.0,>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas<4.0,>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->catboost) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->catboost) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->catboost) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->catboost) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib->catboost) (3.2.5)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/anaconda3/lib/python3.13/site-packages (from plotly->catboost) (2.7.0)

# %%
from sklearn.metrics import r2_score
from sklearn.model_selection import KFold
import lightgbm as lgb
from catboost import CatBoostRegressor

# %%
train['y'] = np.log1p(train['demand'])
GM = train['demand'].mean()

te_col_defs = {'geohash': 10, 'gh_prefix5': 15, 'gh_prefix4': 20, 'hour': 30,
               'tmin': 30, 'gh_hour': 8, 'gh_bucket': 6, 'tod_bucket': 30}

agg_feat_names = ['te_geohash_std', 'gh_med', 'gh_q25', 'gh_q75', 'gh_hour_med', 'gh_hour_std']

features = ['day', 'tmin', 'hour', 'tod_bucket', 'min_sin', 'min_cos', 'hour_sin', 'hour_cos',
            'lat', 'lon', 'NumberofLanes', 'Temperature', 'temp_missing',
            'LargeVehicles_e', 'Landmarks_e',
            'temp_x_hour', 'lanes_x_road', 'lanes_x_hour', 'lat_x_lon',
            'temp_x_lanes'] + road_cols + weather_cols

te_feature_names = ['te_' + col for col in te_col_defs.keys()]
features += te_feature_names + agg_feat_names

print(f"Total features: {len(features)}")
# Out:
# Total features: 43

# %%
# Compute target encodings for TEST from full train
for col, m in te_col_defs.items():
    agg = train.groupby(col)['demand'].agg(['count', 'mean'])
    smooth = (agg['count'] * agg['mean'] + m * GM) / (agg['count'] + m)
    test['te_' + col] = test[col].map(smooth).fillna(GM).values

# %%
# Test agg features from full train
gh_std_full = train.groupby('geohash')['demand'].std().fillna(0)
test['te_geohash_std'] = test['geohash'].map(gh_std_full).fillna(0)

# %%
for q, name in [(0.5, 'med'), (0.25, 'q25'), (0.75, 'q75')]:
    qv = train.groupby('geohash')['demand'].quantile(q)
    test['gh_' + name] = test['geohash'].map(qv).fillna(GM)

# %%
gh_hour_agg_full = train.groupby(['geohash', 'hour'])['demand'].agg(['median', 'std']).fillna(0)
gh_hour_agg_full.columns = ['gh_hour_med', 'gh_hour_std']
test = test.join(gh_hour_agg_full, on=['geohash', 'hour'])
test['gh_hour_med'].fillna(GM, inplace=True)
test['gh_hour_std'].fillna(0, inplace=True)

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)

X_all = train.copy()
y_all = train['y'].values

oof_xgb = np.zeros(len(train))
oof_lgb = np.zeros(len(train))
oof_cb  = np.zeros(len(train))
test_xgb = np.zeros(len(test))
test_lgb = np.zeros(len(test))
test_cb  = np.zeros(len(test))

# %%
for fold, (tr_idx, val_idx) in enumerate(kf.split(X_all)):
    print(f"\n=== Fold {fold} ===")

    train_fold = X_all.iloc[tr_idx].copy()
    val_fold   = X_all.iloc[val_idx].copy()
    
    for col, m in te_col_defs.items():
        agg = train_fold.groupby(col)['demand'].agg(['count', 'mean'])
        smooth = (agg['count'] * agg['mean'] + m * GM) / (agg['count'] + m)
        train_fold['te_' + col] = train_fold[col].map(smooth).fillna(GM).values
        val_fold['te_' + col]   = val_fold[col].map(smooth).fillna(GM).values

    gh_std = train_fold.groupby('geohash')['demand'].std().fillna(0)
    train_fold['te_geohash_std'] = train_fold['geohash'].map(gh_std).fillna(0)
    val_fold['te_geohash_std']   = val_fold['geohash'].map(gh_std).fillna(0)

    for q, name in [(0.5, 'med'), (0.25, 'q25'), (0.75, 'q75')]:
        qv = train_fold.groupby('geohash')['demand'].quantile(q)
        train_fold['gh_' + name] = train_fold['geohash'].map(qv).fillna(GM)
        val_fold['gh_' + name]   = val_fold['geohash'].map(qv).fillna(GM)

    gh_hour_agg = train_fold.groupby(['geohash', 'hour'])['demand'].agg(['median', 'std']).fillna(0)
    gh_hour_agg.columns = ['gh_hour_med', 'gh_hour_std']
    train_fold = train_fold.join(gh_hour_agg, on=['geohash', 'hour'], rsuffix='_new')
    val_fold   = val_fold.join(gh_hour_agg, on=['geohash', 'hour'], rsuffix='_new')
    for c in ['gh_hour_med', 'gh_hour_std']:
        if c + '_new' in train_fold.columns:
            train_fold[c] = train_fold[c + '_new']
            val_fold[c] = val_fold[c + '_new']
            train_fold.drop(columns=[c + '_new'], inplace=True)
            val_fold.drop(columns=[c + '_new'], inplace=True)
    train_fold['gh_hour_med'].fillna(GM, inplace=True)
    val_fold['gh_hour_med'].fillna(GM, inplace=True)
    train_fold['gh_hour_std'].fillna(0, inplace=True)
    val_fold['gh_hour_std'].fillna(0, inplace=True)

    X_f_tr = train_fold[features]
    y_f_tr = train_fold['y']
    X_f_val = val_fold[features]
    y_f_val = val_fold['y']

    # XGBoost
    m_xgb = xgb.XGBRegressor(
        n_estimators=4000, learning_rate=0.02,
        max_depth=7, min_child_weight=5,
        subsample=0.8, colsample_bytree=0.7,
        reg_alpha=1.0, reg_lambda=2.0,
        gamma=0.1, random_state=42, n_jobs=-1,
        early_stopping_rounds=120, eval_metric='rmse'
    )
    m_xgb.fit(X_f_tr, y_f_tr, eval_set=[(X_f_val, y_f_val)], verbose=False)
    oof_xgb[val_idx] = m_xgb.predict(X_f_val)
    test_xgb += m_xgb.predict(test[features]) / 5

    # LightGBM
    m_lgb = lgb.LGBMRegressor(
        n_estimators=4000, learning_rate=0.02,
        max_depth=7, num_leaves=127,
        min_child_samples=25,
        subsample=0.8, colsample_bytree=0.7,
        reg_alpha=1.0, reg_lambda=2.0,
        random_state=42, n_jobs=-1, verbose=-1
    )
    m_lgb.fit(X_f_tr, y_f_tr, eval_set=[(X_f_val, y_f_val)],
              callbacks=[lgb.early_stopping(120), lgb.log_evaluation(0)])
    oof_lgb[val_idx] = m_lgb.predict(X_f_val)
    test_lgb += m_lgb.predict(test[features]) / 5

    # CatBoost
    m_cb = CatBoostRegressor(
        iterations=4000, learning_rate=0.02,
        depth=7, l2_leaf_reg=2.0,
        subsample=0.8, random_seed=42, verbose=0,
        early_stopping_rounds=120
    )
    m_cb.fit(X_f_tr, y_f_tr, eval_set=(X_f_val, y_f_val))
    oof_cb[val_idx] = m_cb.predict(X_f_val)
    test_cb += m_cb.predict(test[features]) / 5

    v_xgb = r2_score(train['demand'].iloc[val_idx], np.clip(np.expm1(oof_xgb[val_idx]), 1e-7, 1))
    v_lgb = r2_score(train['demand'].iloc[val_idx], np.clip(np.expm1(oof_lgb[val_idx]), 1e-7, 1))
    v_cb  = r2_score(train['demand'].iloc[val_idx], np.clip(np.expm1(oof_cb[val_idx]), 1e-7, 1))
    print(f"  XGB={v_xgb:.4f}  LGB={v_lgb:.4f}  CB={v_cb:.4f}")
# Out:
# === Fold 0 ===
# Training until validation scores don't improve for 120 rounds
# Early stopping, best iteration is:
# [1213]	valid_0's l2: 0.00166225
#   XGB=0.8700  LGB=0.8787  CB=0.8593
#
# === Fold 1 ===
# Training until validation scores don't improve for 120 rounds
# Early stopping, best iteration is:
# [1143]	valid_0's l2: 0.00186533
#   XGB=0.8413  LGB=0.8589  CB=0.8374
#
# === Fold 2 ===
# Training until validation scores don't improve for 120 rounds
# Early stopping, best iteration is:
# [786]	valid_0's l2: 0.00199492
#   XGB=0.8231  LGB=0.8377  CB=0.8184
#
# === Fold 3 ===
# Training until validation scores don't improve for 120 rounds
# Early stopping, best iteration is:
# [502]	valid_0's l2: 0.00174945
#   XGB=0.8536  LGB=0.8600  CB=0.8484
#
# === Fold 4 ===
# Training until validation scores don't improve for 120 rounds
# Early stopping, best iteration is:
# [1183]	valid_0's l2: 0.00157937
#   XGB=0.8745  LGB=0.8866  CB=0.8695

# %%
p_oof_xgb = np.clip(np.expm1(oof_xgb), 1e-7, 1.0)
p_oof_lgb = np.clip(np.expm1(oof_lgb), 1e-7, 1.0)
p_oof_cb  = np.clip(np.expm1(oof_cb), 1e-7, 1.0)
y_true = train['demand'].values

print("OOF XGB R2:", round(r2_score(y_true, p_oof_xgb), 4))
print("OOF LGB R2:", round(r2_score(y_true, p_oof_lgb), 4))
print("OOF CB  R2:", round(r2_score(y_true, p_oof_cb), 4))
# Out:
# OOF XGB R2: 0.8525
# OOF LGB R2: 0.8645
# OOF CB  R2: 0.8466

# %%
best_r2 = -1
best_w = None
for w1 in np.arange(0.1, 0.7, 0.05):
    for w2 in np.arange(0.1, 0.7, 0.05):
        w3 = 1 - w1 - w2
        if w3 < 0.05: continue
        p_ens = w1 * p_oof_xgb + w2 * p_oof_lgb + w3 * p_oof_cb
        r2 = r2_score(y_true, p_ens)
        if r2 > best_r2:
            best_r2 = r2
            best_w = (round(w1, 2), round(w2, 2), round(w3, 2))

print(f"Best weights: XGB={best_w[0]}, LGB={best_w[1]}, CB={best_w[2]}")
print(f"OOF Ensemble R2: {best_r2:.4f}")

score = max(0, 100 * best_r2)
print(f"\n>>> Competition Score = max(0, 100 * R2) = {score:.2f}")
# Out:
# Best weights: XGB=0.25, LGB=0.65, CB=0.1
# OOF Ensemble R2: 0.8614
#
# >>> Competition Score = max(0, 100 * R2) = 86.14

# %%
t_xgb = np.clip(np.expm1(test_xgb), 1e-7, 1.0)
t_lgb = np.clip(np.expm1(test_lgb), 1e-7, 1.0)
t_cb  = np.clip(np.expm1(test_cb), 1e-7, 1.0)

test['demand'] = best_w[0] * t_xgb + best_w[1] * t_lgb + best_w[2] * t_cb
submission = test[['Index', 'demand']]
submission.to_csv('submission.csv', index=False)

print(f"Submission shape: {submission.shape}")  # should be (41778, 2)
print(f"Columns: {list(submission.columns)}")
print(f"Demand range: [{submission['demand'].min():.6f}, {submission['demand'].max():.6f}]")
print(f"\nSubmission saved to submission.csv")
# Out:
# Submission shape: (41778, 2)
# Columns: ['Index', 'demand']
# Demand range: [0.003684, 0.987270]
#
# Submission saved to submission.csv
